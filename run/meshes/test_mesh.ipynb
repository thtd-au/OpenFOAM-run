# %%
from write_block_mesh_dict import write_block_mesh_dict
# import importlib
# import write_block_mesh_dict

# importlib.reload(write_block_mesh_dict)

# %%
write_block_mesh_dict(
    L=0.1,
    w=0.05,
    d=0.005,
    nx=40,
    ny=40,
    nz=100,
    y_refinement=5,
    output_path="/home/au672287/OpenFOAM/au672287-v2512/run/meshes/test/channel0/system/blockMeshDict"
)
# Out:
# Wrote blockMeshDict to: /home/au672287/OpenFOAM/au672287-v2512/run/meshes/test/channel0/system/blockMeshDict
